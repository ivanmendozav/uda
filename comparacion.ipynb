# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file_datos ="consumo_estimado_corregido_aceleracion.csv"
datos_corregidos = pd.read_csv(file_datos)
datos_corregidos
# Out:
#       latitude  longitude  height   distance   sum_distance     slope  \
# 0    -3.476898 -79.169502  2321.3  32.028551      32.028551  0.000000
# 1    -3.477153 -79.169647  2321.3  32.489600      64.518152  0.000000
# 2    -3.477430 -79.169754  2321.3  32.870444      97.388596  0.000000
# 3    -3.477718 -79.169830  2321.3  32.960892     130.349487  0.000000
# 4    -3.478016 -79.169914  2349.1  34.262563     164.612050  0.811381
# ...        ...        ...     ...        ...            ...       ...
# 4216 -3.987093 -79.202934  2058.3   0.120590  102985.075008  0.000000
# 4217 -3.987094 -79.202934  2058.3   0.120590  102985.195598  0.000000
# 4218 -3.987095 -79.202934  2058.3   0.120590  102985.316188  0.000000
# 4219 -3.987096 -79.202934  2058.3   0.120590  102985.436778  0.000000
# 4220 -3.987097 -79.202934  2058.3   0.120590  102985.557368  0.000000
#
#                      date          utm_x         utm_y  velocidad_gps  ...  \
# ...

# %%
plt.plot(datos_corregidos['velocidad_ms'],label='Velocidad Calculada')
plt.plot(datos_corregidos['velocidad_gps-ms'],label='Velocidad GPS')
plt.legend()

# %%
plt.plot(datos_corregidos['aceleracion_ms'],label='Aceleración Calculada')
plt.plot(datos_corregidos['aceleracion_gps'],label='Aceleración Calculada GPS')
plt.legend()

# %%
file_datos ="consumo_estimado_sin_corregir.csv"
datos_sin_corregir = pd.read_csv(file_datos)
datos_sin_corregir
# Out:
#       latitude  longitude  height   distance  sum_distance     slope  \
# 0    -3.476464 -79.169121  2321.3  32.045666     64.296855  0.000000
# 1    -3.476898 -79.169502  2321.3  32.028551    128.476369  0.000000
# 2    -3.477153 -79.169647  2321.3  32.489600    160.965969  0.000000
# 3    -3.477430 -79.169754  2321.3  32.870444    193.836413  0.000000
# 4    -3.477718 -79.169830  2321.3  32.960891    226.797304  0.000000
# ...        ...        ...     ...        ...           ...       ...
# 1765 -3.987100 -79.202934  2058.3   0.120590  98932.970506  0.000000
# 1766 -3.987222 -79.202927  2058.3   7.743016  98947.795165  0.000000
# 1767 -3.987260 -79.202866  2059.3   7.982333  98955.777498  0.125277
# 1768 -3.987276 -79.202782  2059.2   2.585885  98965.299037  0.000000
# 1769 -3.987276 -79.202782  2059.2   0.010000  98965.309037  0.000000
#
#                      date          utm_x         utm_y  velocidad_gps  ...  \
# ...

# %%
datos_sin_corregir['potencia_rueda']
# Out:
# 0         5837.734159
# 1         4989.286700
# 2         3252.374327
# 3         2112.973830
# 4         7673.370765
#             ...
# 1765         4.855361
# 1766      1121.453896
# 1767    101194.996958
# 1768         2.872792
# 1769         1.338093
# Name: potencia_rueda, Length: 1770, dtype: float64

# %%
datos_corregidos['timestamp']
# Out:
# 0       1.502817e+09
# 1       1.502817e+09
# 2       1.502817e+09
# 3       1.502817e+09
# 4       1.502817e+09
#             ...
# 4216    1.502823e+09
# 4217    1.502823e+09
# 4218    1.502823e+09
# 4219    1.502823e+09
# 4220    1.502823e+09
# Name: timestamp, Length: 4221, dtype: float64

# %%
datos_sin_corregir.timestamp[0]
# Out:
# 1502816918.0

# %%
datos_corregidos.timestamp[0]
# Out:
# 1502816920.0

# %%
datos_corregidos.timestamp[len(datos_corregidos.timestamp) - 1]
# Out:
# 1502822873.0

# %%
datos_sin_corregir.timestamp[len(datos_sin_corregir.timestamp) - 1]
# Out:
# 1502822896.0

# %%
tiempo_viaje_sin_corr  = datos_sin_corregir.timestamp[len(datos_sin_corregir.timestamp) - 1] - datos_sin_corregir.timestamp[0]
tiempo_viaje_sin_corr / 3600
# Out:
# 1.6605555555555556

# %%
tiempo_viaje_corr  = datos_corregidos.timestamp[len(datos_corregidos.timestamp) - 1] - datos_corregidos.timestamp[0]
tiempo_viaje_corr / 3600
# Out:
# 1.6536111111111111

# %%
plt.figure(figsize=(12,10))
plt.plot(datos_corregidos['timestamp'][1005:10000], datos_corregidos['potencia_rueda'][1005:10000], '-o',label='Potencia Corregida')

plt.plot(datos_sin_corregir['timestamp'][1005:10000], datos_sin_corregir['potencia_rueda'][1005:10000], '-o',label='Potencia', alpha=0.3)



plt.legend()
plt.show()

# %%
#Esto quedaría en GWh
(np.sum(datos_corregidos['potencia_rueda']) * 3.8) / 1e9

# %%
(np.sum(datos_sin_corregir['potencia_rueda']) * 3.8) / 1e9

# %%
plt.figure(figsize=(10,5))
plt.plot(datos_corregidos['utm_x'], datos_corregidos['caudal_inst'],'-o',label='Consumo Estimado')
plt.plot(datos_corregidos['utm_x'], datos_corregidos['consumo_inst'], '-o',label='Consumo Flujometro')




plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(datos_corregidos['utm_x'], datos_corregidos['caudal_inst'],'-o',label='Consumo Estimado')
plt.plot(datos_corregidos['utm_x'], datos_corregidos['consumo_inst'], '-o',label='Consumo Flujometro')




plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(datos_sin_corregir['timestamp'], datos_sin_corregir['caudal_inst'],'-o',label='Consumo Estimado Sin', alpha=0.2)
plt.plot(datos_sin_corregir['timestamp'], datos_sin_corregir['consumo_inst'], '-o',label='Consumo Flujometro Sin')



plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,10))
plt.plot(datos_corregidos['sum_distance'], datos_corregidos['caudal_inst'],'-o',label='Consumo Estimado')
plt.plot(datos_corregidos['sum_distance'], datos_corregidos['consumo_inst'], '-o',label='Consumo Flujometro')

plt.plot(datos_sin_corregir['sum_distance'], datos_sin_corregir['caudal_inst'],'-o',label='Consumo Estimado Sin')
plt.plot(datos_sin_corregir['sum_distance'], datos_sin_corregir['consumo_inst'], '-o',label='Consumo Flujometro Sin')



plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,10))
plt.plot(datos_corregidos['sum_distance'], datos_corregidos['consumo_inst'], '-o',label='Consumo Flujometro')

plt.plot(datos_sin_corregir['sum_distance'], datos_sin_corregir['consumo_inst'], '-o',label='Consumo Flujometro Sin', alpha=0.3)



plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,10))
plt.plot(datos_corregidos['sum_distance'], datos_corregidos['caudal_inst'], '-o',label='Consumo Flujometro')

plt.plot(datos_sin_corregir['sum_distance'], datos_sin_corregir['caudal_inst'], '-o',label='Consumo Flujometro Sin', alpha=0.3)



plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,10))
plt.plot(datos_corregidos['sum_distance'], datos_corregidos['caudal_inst'],'-o',label='Consumo Estimado')


plt.plot(datos_sin_corregir['sum_distance'], datos_sin_corregir['caudal_inst'],'-o',label='Consumo Estimado Sin', alpha=0.2)

plt.plot(datos_sin_corregir['sum_distance'], datos_sin_corregir['consumo_inst'], '-o',label='Consumo Flujometro', alpha=0.4)


plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,10))

plt.plot(datos_corregidos['sum_distance'], datos_corregidos['consumo_inst'], '-o',label='Consumo Flujometro')

plt.plot(datos_sin_corregir['sum_distance'], datos_sin_corregir['consumo_inst'], '-o',label='Consumo Flujometro Sin')



plt.legend()
plt.show()
